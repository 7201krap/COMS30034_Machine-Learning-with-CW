# %%
from IPython.display import Image

# %% [markdown]
# ### Definitions

# %% [markdown]
# - Markov process : a sequence of possible events in which the probability of each state depends only on the state attained in the previous state
# - Transition probabilities : the probability that an event will transition to a new state or stay the same

# %%
Image(filename="cost_function.png", width=900, height=600)
# https://www.youtube.com/watch?v=1_MtUNv_YuI

# %% [markdown]
# S = {1, 2, 3}
#
# Probability of state x --> other states S - x : sums to 1. However, probability of other states S - x --> state x : doesn't have to be 1.

# %% [markdown]
# ### What we will learn

# %% [markdown]
# - Hidden Markov process : a sequence of possible events in which the probaility of each state depends only on the state attained in the previous state.
# - Latent features : features that are not directly observable, and are hard to label/interpret
# - Emission probabilities : determines probabilites of observations given a hidden state

# %%
Image(filename="cost_function_hhm.png", width=900, height=600)

# %% [markdown]
# - Two hidden features : rainy and sunny
# - Three observable features : walk shop and clean
